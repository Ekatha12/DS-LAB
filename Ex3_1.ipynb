# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,6,18])
y = np.array([3,10,12,20])

plt.plot(x,y, marker ='o',color='red',ms='20', mec='green',linestyle= 'dashed')
plt.show()
