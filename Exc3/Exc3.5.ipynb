# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([10,20,30])
y=np.array([2,4,6])
plt.subplot(1,2,1)
plt.plot(x,y)
x1=np.array([1,4,6])
y1=np.array([3,6,9])
plt.subplot(1,2,2)
plt.plot(x1,y1)
plt.show()
