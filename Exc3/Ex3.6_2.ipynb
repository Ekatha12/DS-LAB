# %%
import matplotlib.pyplot as plt
y = ['Java', 'Python', 'Php','Javascript','C#','C++']
x = [22.2, 17.6,8.8,8,77,6.7]
plt.barh(y,x, color='r')
plt.xlabel('Programming Languages')
plt.ylabel('Popularity')
plt.title('Horizontal Bar graph')
plt.show()
